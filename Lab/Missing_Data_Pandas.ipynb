# %%
import numpy as np
import pandas as pd

# %%
employee_list = [['James', 36, 75, 5428000],
               ['Villers', 38, 74, 3428000],
               ['VKole', 31, 70, 8428000],
               ['Smith', 34, 80, 4428000],
               ['Gayle', 40, 100, 4528000],
               ['Adam', 40, np.nan, 4528000],
               ['Rooter', 33, 72, 7028000],
               ['Peterson', 42, 85, 2528000],
               ['lynda', 42, 85, np.nan],
               [np.nan, 42, 85, np.nan],
               ['Jenny', np.nan, 100, 25632],
               ['Kenn', np.nan, 110, 25632],
                ['Aly', np.nan, 90, 25582],
               ['John', 41, 85, 1528000]]

df = pd.DataFrame(employee_list, columns=['Name', 'Age', 'Weight', 'Salary'])

# %%
rows, cols = df.shape
 
print(f'Rows: {rows}')
print(f'Cols: {cols}')
# Out:
# Rows: 14
# Cols: 4

# %%
df
# Out:
#         Name   Age  Weight     Salary
# 0      James  36.0    75.0  5428000.0
# 1    Villers  38.0    74.0  3428000.0
# 2      VKole  31.0    70.0  8428000.0
# 3      Smith  34.0    80.0  4428000.0
# 4      Gayle  40.0   100.0  4528000.0
# 5       Adam  40.0     NaN  4528000.0
# 6     Rooter  33.0    72.0  7028000.0
# 7   Peterson  42.0    85.0  2528000.0
# 8      lynda  42.0    85.0        NaN
# 9        NaN  42.0    85.0        NaN
# 10     Jenny   NaN   100.0    25632.0
# 11      Kenn   NaN   110.0    25632.0
# 12       Aly   NaN    90.0    25582.0
# 13      John  41.0    85.0  1528000.0

# %%
df.isnull().sum()
# Out:
# Name      1
# Age       3
# Weight    1
# Salary    2
# dtype: int64

# %%
dropped_df = df.dropna()

print(dropped_df)
# Out:
#         Name   Age  Weight     Salary
# 0      James  36.0    75.0  5428000.0
# 1    Villers  38.0    74.0  3428000.0
# 2      VKole  31.0    70.0  8428000.0
# 3      Smith  34.0    80.0  4428000.0
# 4      Gayle  40.0   100.0  4528000.0
# 6     Rooter  33.0    72.0  7028000.0
# 7   Peterson  42.0    85.0  2528000.0
# 13      John  41.0    85.0  1528000.0

# %%
filled_df = df.fillna('None')

filled_df
# Out:
#         Name   Age Weight     Salary
# 0      James  36.0   75.0  5428000.0
# 1    Villers  38.0   74.0  3428000.0
# 2      VKole  31.0   70.0  8428000.0
# 3      Smith  34.0   80.0  4428000.0
# 4      Gayle  40.0  100.0  4528000.0
# 5       Adam  40.0   None  4528000.0
# 6     Rooter  33.0   72.0  7028000.0
# 7   Peterson  42.0   85.0  2528000.0
# 8      lynda  42.0   85.0       None
# 9       None  42.0   85.0       None
# 10     Jenny  None  100.0    25632.0
# 11      Kenn  None  110.0    25632.0
# 12       Aly  None   90.0    25582.0
# 13      John  41.0   85.0  1528000.0

# %%
filled_df.isnull().sum()
# Out:
# Name      0
# Age       0
# Weight    0
# Salary    0
# dtype: int64

# %%
specific_cols = df[['Weight', 'Age']].fillna('Pending')

specific_cols
# Out:
#      Weight      Age
# 0      75.0     36.0
# 1      74.0     38.0
# 2      70.0     31.0
# 3      80.0     34.0
# 4     100.0     40.0
# 5   Pending     40.0
# 6      72.0     33.0
# 7      85.0     42.0
# 8      85.0     42.0
# 9      85.0     42.0
# 10    100.0  Pending
# 11    110.0  Pending
# 12     90.0  Pending
# 13     85.0     41.0

# %%
specific_cols = df[['Weight', 'Age']].fillna('Pending')

specific_cols
# Out:
#      Weight      Age
# 0      75.0     36.0
# 1      74.0     38.0
# 2      70.0     31.0
# 3      80.0     34.0
# 4     100.0     40.0
# 5   Pending     40.0
# 6      72.0     33.0
# 7      85.0     42.0
# 8      85.0     42.0
# 9      85.0     42.0
# 10    100.0  Pending
# 11    110.0  Pending
# 12     90.0  Pending
# 13     85.0     41.0

# %%
technologies = {
    'Courses':["Spark",np.nan,"Hadoop","Python","pandas",np.nan,"Java"],
    'Fee' :[20000,25000, np.nan,22000,24000,np.nan,22000],
    'Duration':[np.nan,'40days','35days', np.nan,'60days','50days','55days'],
    'Discount':[1000,np.nan,1500,np.nan,2500,2100,np.nan]
              }

tech = pd.DataFrame(technologies)

# %%
rows, cols = tech.shape

print('Rows', rows)
print('Cols', cols)
# Out:
# Rows 7
# Cols 4

# %%
tech.isnull().sum()
# Out:
# Courses     2
# Fee         2
# Duration    2
# Discount    3
# dtype: int64

# %%
tech2 = tech.replace(np.nan, '')

tech2
# Out:
#   Courses      Fee Duration Discount
# 0   Spark  20000.0            1000.0
# 1          25000.0   40days
# 2  Hadoop            35days   1500.0
# 3  Python  22000.0
# 4  pandas  24000.0   60days   2500.0
# 5                    50days   2100.0
# 6    Java  22000.0   55days

# %%
tech3 = tech.replace({'Courses': np.nan, 'Fee': np.nan}, 'PENDING')

tech3
# Out:
#    Courses      Fee Duration  Discount
# 0    Spark  20000.0      NaN    1000.0
# 1  PENDING  25000.0   40days       NaN
# 2   Hadoop  PENDING   35days    1500.0
# 3   Python  22000.0      NaN       NaN
# 4   pandas  24000.0   60days    2500.0
# 5  PENDING  PENDING   50days    2100.0
# 6     Java  22000.0   55days       NaN

# %%
tech.fillna('')

tech
# Out:
#   Courses      Fee Duration  Discount
# 0   Spark  20000.0      NaN    1000.0
# 1     NaN  25000.0   40days       NaN
# 2  Hadoop      NaN   35days    1500.0
# 3  Python  22000.0      NaN       NaN
# 4  pandas  24000.0   60days    2500.0
# 5     NaN      NaN   50days    2100.0
# 6    Java  22000.0   55days       NaN

# %%
emp_df = pd.read_csv('data/employee.csv')

emp_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 emp_df = pd.read_csv('data/employee.csv')
#       2
#       3 emp_df
#
# File c:\Users\Owner\Documents\1. Per Scholas\Lab386..0\PandasFunctions\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Owner\Documents\1. Per Scholas\Lab386..0\PandasFunctions\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\Owner\Documents\1. Per Scholas\Lab386..0\PandasFunctions\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Owner\Documents\1. Per Scholas\Lab386..0\PandasFunctions\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\Owner\Documents\1. Per Scholas\Lab386..0\PandasFunctions\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/employee.csv'

# %%
emp_df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 emp_df.isnull().sum()
#
# NameError: name 'emp_df' is not defined
